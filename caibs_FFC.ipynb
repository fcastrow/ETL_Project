# %%
import pandas as pd
import numpy as np
import datetime

# %%
csv_file = "crime_and_incarceration_by_state.csv"
caibs_df = pd.read_csv(csv_file)
caibs_df.head()
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                    NaN
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0              NaN               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# ...

# %%
#new_Border_Crossing_df = Border_Crossing_df[["Port Name", "State", "Border", "Date", "Value"]].copy()
#new_Border_Crossing_df.head()

# %%
#new_Border_Crossing_df = new_Border_Crossing_df.rename(columns={"Port Name": "Crossing_City", 
#                                                                "Value": "Crossing_Count"})
#new_Border_Crossing_df.head()

# %%
#new_Border_Crossing_df['Year'] = pd.DatetimeIndex(new_Border_Crossing_df['Date']).year
#new_Border_Crossing_df.head()

# %%
#Grouped_Border_Crossing = new_Border_Crossing_df.groupby(['State', 'Year', 'Border'])['Crossing_Count'].sum()

#FinalBorderCrossing_df = pd.DataFrame(Grouped_Border_Crossing).reset_index()

#FinalBorderCrossing_df

# %%
# FinalBorderCrossing_df.to_excel("output.xlsx")

# %%
from sqlalchemy import create_engine
rds_connection_string = "postgres: @localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
caibs_df.to_sql(name='crime_and_incarceration_by_state', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from "crime_and_incarceration_by_state"', con=engine).head()
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                   None
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0             None               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# ...
